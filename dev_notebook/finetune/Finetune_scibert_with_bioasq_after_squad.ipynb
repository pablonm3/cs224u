# %%
import argparse
import glob
import logging
import os
import random
import timeit

#this reloads the module ( required when we updated the module offline)
# %load_ext autoreload
# %autoreload 2

import torch
import importlib #import reload
import torch.nn as nn
from transformers import *
from my_run_squad import main as my_main # import main as my_main

#importlib.reload(my_run_squad)

# %%
#tokenizer = AutoTokenizer.from_pretrained("output_finetuned_model/squad")

# %%
# load model trained on squad
#model = AutoModelForQuestionAnswering.from_pretrained("output_finetuned_model/squad")

# %%
#model.train()
torch.cuda.empty_cache()

# %%
torch.cuda.empty_cache()
model_path = "output_finetuned_model/squad"
base_path = os.path.abspath('')
grand_parent_path =os.path.abspath('..\..')
#print(grand_parent_path)

# fine tune with squad v2
out_dir = os.path.join(base_path,"output_finetuned_model", "bioasq_test")
train_dir = os.path.join(base_path,"bioasq_data\\train_combined", "training8b_squad_format_300.json")
eval_dir = os.path.join(base_path,"bioasq_data\\test_combined", "BioASQ-task8bPhaseB-testset1_squad_format.json")


#print(out_dir)
#print(train_dir)
#print(eval_dir)

my_main(model_path,out_dir,train_dir,eval_dir)
# Out:
# {'model_type': 'bert', 'model_name_or_path': 'output_finetuned_model/squad', 'output_dir': 'D:\\stanford_courses\\nlu-all\\final_project\\cs224u\\dev_notebook\\finetune\\output_finetuned_model\\bioasq_test', 'data_dir': None, 'train_file': 'D:\\stanford_courses\\nlu-all\\final_project\\cs224u\\dev_notebook\\finetune\\bioasq_data\\train_combined\\training8b_squad_format_300.json', 'predict_file': 'D:\\stanford_courses\\nlu-all\\final_project\\cs224u\\dev_notebook\\finetune\\bioasq_data\\test_combined\\BioASQ-task8bPhaseB-testset1_squad_format.json', 'config_name': '', 'tokenizer_name': '', 'cache_dir': '', 'version_2_with_negative': True, 'null_score_diff_threshold': 0.0, 'max_seq_length': 384, 'doc_stride': 128, 'max_query_length': 64, 'do_train': True, 'do_eval': True, 'evaluate_during_training': False, 'do_lower_case': True, 'per_gpu_train_batch_size': 4, 'per_gpu_eval_batch_size': 64, 'learning_rate': 3e-05, 'gradient_accumulation_steps': 1, 'weight_decay': 0.0, 'adam_epsilon': 1e-08, 'max_grad_norm': 1.0, 'num_train_epochs': 3.0, 'max_steps': -1, 'warmup_steps': 550, 'n_best_size': 20, 'max_answer_length': 128, 'verbose_logging': False, 'lang_id': 0, 'logging_steps': 50, 'save_steps': 2000, 'eval_all_checkpoints': False, 'no_cuda': False, 'overwrite_output_dir': False, 'overwrite_cache': False, 'seed': 42, 'local_rank': -1, 'fp16': False, 'fp16_opt_level': None, 'server_ip': '', 'server_port': '', 'threads': 4}
# 05/06/2020 10:38:55 - WARNING - my_run_squad -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 05/06/2020 10:38:55 - INFO - transformers.configuration_utils -   loading configuration file output_finetuned_model/squad\config.json
# 05/06/2020 10:38:55 - INFO - transformers.configuration_utils -   Model config BertConfig {
#   "_num_labels": 2,
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bad_words_ids": null,
#   "bos_token_id": null,
#   "decoder_start_token_id": null,
#   "do_sample": false,
#   "early_stopping": false,
#   "eos_token_id": null,
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "is_decoder": false,
#   "is_encoder_decoder": false,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1
#   },
#   "layer_norm_eps": 1e-12,
#   "length_penalty": 1.0,
#   "max_length": 20,
#   "max_position_embeddings": 512,
#   "min_length": 0,
#   "model_type": "bert",
#   "no_repeat_ngram_size": 0,
#   "num_attention_heads": 12,
#   "num_beams": 1,
#   "num_hidden_layers": 12,
#   "num_return_sequences": 1,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "output_past": true,
#   "pad_token_id": 0,
#   "prefix": null,
#   "pruned_heads": {},
#   "repetition_penalty": 1.0,
#   "task_specific_params": null,
#   "temperature": 1.0,
#   "top_k": 50,
#   "top_p": 1.0,
#   "torchscript": false,
#   "type_vocab_size": 2,
#   "use_bfloat16": false,
#   "vocab_size": 31090
# }
#
# 05/06/2020 10:38:55 - INFO - transformers.configuration_utils -   loading configuration file output_finetuned_model/squad\config.json
# 05/06/2020 10:38:55 - INFO - transformers.configuration_utils -   Model config BertConfig {
#   "_num_labels": 2,
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bad_words_ids": null,
#   "bos_token_id": null,
#   "decoder_start_token_id": null,
#   "do_sample": false,
#   "early_stopping": false,
#   "eos_token_id": null,
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "is_decoder": false,
#   "is_encoder_decoder": false,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1
#   },
#   "layer_norm_eps": 1e-12,
#   "length_penalty": 1.0,
#   "max_length": 20,
#   "max_position_embeddings": 512,
#   "min_length": 0,
#   "model_type": "bert",
#   "no_repeat_ngram_size": 0,
#   "num_attention_heads": 12,
#   "num_beams": 1,
#   "num_hidden_layers": 12,
#   "num_return_sequences": 1,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "output_past": true,
#   "pad_token_id": 0,
#   "prefix": null,
#   "pruned_heads": {},
#   "repetition_penalty": 1.0,
#   "task_specific_params": null,
#   "temperature": 1.0,
#   "top_k": 50,
#   "top_p": 1.0,
#   "torchscript": false,
#   "type_vocab_size": 2,
#   "use_bfloat16": false,
#   "vocab_size": 31090
# }
#
# 05/06/2020 10:38:55 - INFO - transformers.tokenization_utils -   Model name 'output_finetuned_model/squad' not found in model shortcut name list (bert-base-uncased, bert-large-uncased, bert-base-cased, bert-large-cased, bert-base-multilingual-uncased, bert-base-multilingual-cased, bert-base-chinese, bert-base-german-cased, bert-large-uncased-whole-word-masking, bert-large-cased-whole-word-masking, bert-large-uncased-whole-word-masking-finetuned-squad, bert-large-cased-whole-word-masking-finetuned-squad, bert-base-cased-finetuned-mrpc, bert-base-german-dbmdz-cased, bert-base-german-dbmdz-uncased, bert-base-finnish-cased-v1, bert-base-finnish-uncased-v1, bert-base-dutch-cased). Assuming 'output_finetuned_model/squad' is a path, a model identifier, or url to a directory containing tokenizer files.
# 05/06/2020 10:38:55 - INFO - transformers.tokenization_utils -   Didn't find file output_finetuned_model/squad\added_tokens.json. We won't load it.
# 05/06/2020 10:38:55 - INFO - transformers.tokenization_utils -   loading file output_finetuned_model/squad\vocab.txt
# 05/06/2020 10:38:55 - INFO - transformers.tokenization_utils -   loading file None
# 05/06/2020 10:38:55 - INFO - transformers.tokenization_utils -   loading file output_finetuned_model/squad\special_tokens_map.json
# 05/06/2020 10:38:55 - INFO - transformers.tokenization_utils -   loading file output_finetuned_model/squad\tokenizer_config.json
# 05/06/2020 10:38:55 - INFO - transformers.modeling_utils -   loading weights file output_finetuned_model/squad\pytorch_model.bin
# 05/06/2020 10:38:58 - INFO - my_run_squad -   Training/evaluation parameters Namespace(adam_epsilon=1e-08, cache_dir='', config_name='', data_dir=None, device=device(type='cuda'), do_eval=True, do_lower_case=True, do_train=True, doc_stride=128, eval_all_checkpoints=False, evaluate_during_training=False, fp16=False, fp16_opt_level=None, gradient_accumulation_steps=1, lang_id=0, learning_rate=3e-05, local_rank=-1, logging_steps=50, max_answer_length=128, max_grad_norm=1.0, max_query_length=64, max_seq_length=384, max_steps=-1, model_name_or_path='output_finetuned_model/squad', model_type='bert', n_best_size=20, n_gpu=1, no_cuda=False, null_score_diff_threshold=0.0, num_train_epochs=3.0, output_dir='D:\\stanford_courses\\nlu-all\\final_project\\cs224u\\dev_notebook\\finetune\\output_finetuned_model\\bioasq_test', overwrite_cache=False, overwrite_output_dir=False, per_gpu_eval_batch_size=64, per_gpu_train_batch_size=4, predict_file='D:\\stanford_courses\\nlu-all\\final_project\\cs224u\\dev_notebook\\finetune\\bioasq_data\\test_combined\\BioASQ-task8bPhaseB-testset1_squad_format.json', save_steps=2000, seed=42, server_ip='', server_port='', threads=4, tokenizer_name='', train_file='D:\\stanford_courses\\nlu-all\\final_project\\cs224u\\dev_notebook\\finetune\\bioasq_data\\train_combined\\training8b_squad_format_300.json', verbose_logging=False, version_2_with_negative=True, warmup_steps=550, weight_decay=0.0)
# 05/06/2020 10:38:58 - INFO - my_run_squad -   Loading features from cached file .\cached_train_squad_384
# 05/06/2020 10:38:58 - INFO - my_run_squad -   ***** Running training *****
# 05/06/2020 10:38:58 - INFO - my_run_squad -     Num examples = 3459
# 05/06/2020 10:38:58 - INFO - my_run_squad -     Num Epochs = 3
# 05/06/2020 10:38:58 - INFO - my_run_squad -     Instantaneous batch size per GPU = 4
# 05/06/2020 10:38:58 - INFO - my_run_squad -     Total train batch size (w. parallel, distributed & accumulation) = 4
# 05/06/2020 10:38:58 - INFO - my_run_squad -     Gradient Accumulation steps = 1
# 05/06/2020 10:38:58 - INFO - my_run_squad -     Total optimization steps = 2595
# 05/06/2020 10:38:58 - INFO - my_run_squad -     Starting fine-tuning.
# Epoch:   0%|                                                                                                                         | 0/3 [00:00<?, ?it/s]
# Iteration:   0%|                                                                                                                   | 0/865 [00:00<?, ?it/s]
# Iteration:   0%|                                                                                                           | 1/865 [00:00<08:24,  1.71it/s]
# Iteration:   0%|▏                                                                                                          | 2/865 [00:00<06:54,  2.08it/s]
# Iteration:   0%|▎                                                                                                          | 3/865 [00:01<05:53,  2.44it/s]
# Iteration:   0%|▍                                                                                                          | 4/865 [00:01<05:11,  2.76it/s]
# Iteration:   1%|▌                                                                                                          | 5/865 [00:01<04:41,  3.05it/s]
# Iteration:   1%|▋                                                                                                          | 6/865 [00:01<04:21,  3.29it/s]
# Iteration:   1%|▊                                                                                                          | 7/865 [00:02<04:04,  3.51it/s]
# Iteration:   1%|▉                                                                                                          | 8/865 [00:02<03:52,  3.68it/s]
# Iteration:   1%|█                                                                                                          | 9/865 [00:02<03:45,  3.80it/s]
# Iteration:   1%|█▏                                                                                                        | 10/865 [00:02<03:40,  3.89it/s]
# Iteration:   1%|█▎                                                                                                        | 11/865 [00:03<03:35,  3.97it/s]
# Iteration:   1%|█▍                                                                                                        | 12/865 [00:03<03:35,  3.96it/s]
# Iteration:   2%|█▌                                                                                                        | 13/865 [00:03<03:31,  4.02it/s]
# Iteration:   2%|█▋                                                                                                        | 14/865 [00:03<03:29,  4.07it/s]
# Iteration:   2%|█▊                                                                                                        | 15/865 [00:03<03:25,  4.13it/s]
# Iteration:   2%|█▉                                                                                                        | 16/865 [00:04<03:24,  4.16it/s]
# Iteration:   2%|██                                                                                                        | 17/865 [00:04<03:24,  4.15it/s]
# Iteration:   2%|██▏                                                                                                       | 18/865 [00:04<03:24,  4.14it/s]
# Iteration:   2%|██▎                                                                                                       | 19/865 [00:04<03:22,  4.17it/s]
# Iteration:   2%|██▍                                                                                                       | 20/865 [00:05<03:29,  4.03it/s]
# Iteration:   2%|██▌                                                                                                       | 21/865 [00:05<03:25,  4.10it/s]
# Iteration:   3%|██▋                                                                                                       | 22/865 [00:05<03:23,  4.14it/s]
# Iteration:   3%|██▊                                                                                                       | 23/865 [00:05<03:21,  4.17it/s]
:\stanford_courses\nlu-all\final_project\cs224u\dev_notebook\finetune\output_finetuned_model\bioasq_test
# 05/06/2020 10:49:45 - INFO - transformers.configuration_utils -   Configuration saved in D:\stanford_courses\nlu-all\final_project\cs224u\dev_notebook\finetune\output_finetuned_model\bioasq_test\config.json
# 05/06/2020 10:49:46 - INFO - transformers.modeling_utils -   Model weights saved in D:\stanford_courses\nlu-all\final_project\cs224u\dev_notebook\finetune\output_finetuned_model\bioasq_test\pytorch_model.bin
# 05/06/2020 10:49:46 - INFO - transformers.configuration_utils -   loading configuration file D:\stanford_courses\nlu-all\final_project\cs224u\dev_notebook\finetune\output_finetuned_model\bioasq_test\config.json
# 05/06/2020 10:49:46 - INFO - transformers.configuration_utils -   Model config BertConfig {
#   "_num_labels": 2,
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bad_words_ids": null,
#   "bos_token_id": null,
#   "decoder_start_token_id": null,
#   "do_sample": false,
#   "early_stopping": false,
#   "eos_token_id": null,
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "is_decoder": false,
#   "is_encoder_decoder": false,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1
#   },
#   "layer_norm_eps": 1e-12,
#   "length_penalty": 1.0,
#   "max_length": 20,
#   "max_position_embeddings": 512,
#   "min_length": 0,
#   "model_type": "bert",
#   "no_repeat_ngram_size": 0,
#   "num_attention_heads": 12,
#   "num_beams": 1,
#   "num_hidden_layers": 12,
#   "num_return_sequences": 1,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "output_past": true,
#   "pad_token_id": 0,
#   "prefix": null,
#   "pruned_heads": {},
#   "repetition_penalty": 1.0,
#   "task_specific_params": null,
#   "temperature": 1.0,
#   "top_k": 50,
#   "top_p": 1.0,
#   "torchscript": false,
#   "type_vocab_size": 2,
#   "use_bfloat16": false,
#   "vocab_size": 31090
# }
#
# 05/06/2020 10:49:46 - INFO - transformers.modeling_utils -   loading weights file D:\stanford_courses\nlu-all\final_project\cs224u\dev_notebook\finetune\output_finetuned_model\bioasq_test\pytorch_model.bin
# 05/06/2020 10:49:47 - INFO - transformers.configuration_utils -   loading configuration file D:\stanford_courses\nlu-all\final_project\cs224u\dev_notebook\finetune\output_finetuned_model\bioasq_test\config.json
# 05/06/2020 10:49:47 - INFO - transformers.configuration_utils -   Model config BertConfig {
#   "_num_labels": 2,
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bad_words_ids": null,
#   "bos_token_id": null,
#   "decoder_start_token_id": null,
#   "do_sample": false,
#   "early_stopping": false,
#   "eos_token_id": null,
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "is_decoder": false,
#   "is_encoder_decoder": false,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1
#   },
#   "layer_norm_eps": 1e-12,
#   "length_penalty": 1.0,
#   "max_length": 20,
#   "max_position_embeddings": 512,
#   "min_length": 0,
#   "model_type": "bert",
#   "no_repeat_ngram_size": 0,
#   "num_attention_heads": 12,
#   "num_beams": 1,
#   "num_hidden_layers": 12,
#   "num_return_sequences": 1,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "output_past": true,
#   "pad_token_id": 0,
#   "prefix": null,
#   "pruned_heads": {},
#   "repetition_penalty": 1.0,
#   "task_specific_params": null,
#   "temperature": 1.0,
#   "top_k": 50,
#   "top_p": 1.0,
#   "torchscript": false,
#   "type_vocab_size": 2,
#   "use_bfloat16": false,
#   "vocab_size": 31090
# }
#
# 05/06/2020 10:49:47 - INFO - transformers.tokenization_utils -   Model name 'D:\stanford_courses\nlu-all\final_project\cs224u\dev_notebook\finetune\output_finetuned_model\bioasq_test' not found in model shortcut name list (bert-base-uncased, bert-large-uncased, bert-base-cased, bert-large-cased, bert-base-multilingual-uncased, bert-base-multilingual-cased, bert-base-chinese, bert-base-german-cased, bert-large-uncased-whole-word-masking, bert-large-cased-whole-word-masking, bert-large-uncased-whole-word-masking-finetuned-squad, bert-large-cased-whole-word-masking-finetuned-squad, bert-base-cased-finetuned-mrpc, bert-base-german-dbmdz-cased, bert-base-german-dbmdz-uncased, bert-base-finnish-cased-v1, bert-base-finnish-uncased-v1, bert-base-dutch-cased). Assuming 'D:\stanford_courses\nlu-all\final_project\cs224u\dev_notebook\finetune\output_finetuned_model\bioasq_test' is a path, a model identifier, or url to a directory containing tokenizer files.
# 05/06/2020 10:49:47 - INFO - transformers.tokenization_utils -   Didn't find file D:\stanford_courses\nlu-all\final_project\cs224u\dev_notebook\finetune\output_finetuned_model\bioasq_test\added_tokens.json. We won't load it.
# 05/06/2020 10:49:47 - INFO - transformers.tokenization_utils -   loading file D:\stanford_courses\nlu-all\final_project\cs224u\dev_notebook\finetune\output_finetuned_model\bioasq_test\vocab.txt
# 05/06/2020 10:49:47 - INFO - transformers.tokenization_utils -   loading file None
# 05/06/2020 10:49:47 - INFO - transformers.tokenization_utils -   loading file D:\stanford_courses\nlu-all\final_project\cs224u\dev_notebook\finetune\output_finetuned_model\bioasq_test\special_tokens_map.json
# 05/06/2020 10:49:47 - INFO - transformers.tokenization_utils -   loading file D:\stanford_courses\nlu-all\final_project\cs224u\dev_notebook\finetune\output_finetuned_model\bioasq_test\tokenizer_config.json
# 05/06/2020 10:49:48 - INFO - my_run_squad -   Loading checkpoints saved during training for evaluation
# 05/06/2020 10:49:48 - INFO - my_run_squad -   Evaluate the following checkpoints: ['D:\\stanford_courses\\nlu-all\\final_project\\cs224u\\dev_notebook\\finetune\\output_finetuned_model\\bioasq_test']
# 05/06/2020 10:49:48 - INFO - transformers.configuration_utils -   loading configuration file D:\stanford_courses\nlu-all\final_project\cs224u\dev_notebook\finetune\output_finetuned_model\bioasq_test\config.json
# 05/06/2020 10:49:48 - INFO - transformers.configuration_utils -   Model config BertConfig {
#   "_num_labels": 2,
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bad_words_ids": null,
#   "bos_token_id": null,
#   "decoder_start_token_id": null,
#   "do_sample": false,
#   "early_stopping": false,
#   "eos_token_id": null,
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "is_decoder": false,
#   "is_encoder_decoder": false,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1
#   },
#   "layer_norm_eps": 1e-12,
#   "length_penalty": 1.0,
#   "max_length": 20,
#   "max_position_embeddings": 512,
#   "min_length": 0,
#   "model_type": "bert",
#   "no_repeat_ngram_size": 0,
#   "num_attention_heads": 12,
#   "num_beams": 1,
#   "num_hidden_layers": 12,
#   "num_return_sequences": 1,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "output_past": true,
#   "pad_token_id": 0,
#   "prefix": null,
#   "pruned_heads": {},
#   "repetition_penalty": 1.0,
#   "task_specific_params": null,
#   "temperature": 1.0,
#   "top_k": 50,
#   "top_p": 1.0,
#   "torchscript": false,
#   "type_vocab_size": 2,
#   "use_bfloat16": false,
#   "vocab_size": 31090
# }
# 05/06/2020 10:49:48 - INFO - transformers.modeling_utils -   loading weights file D:\stanford_courses\nlu-all\final_project\cs224u\dev_notebook\finetune\output_finetuned_model\bioasq_test\pytorch_model.bin
# 05/06/2020 10:49:49 - INFO - my_run_squad -   Creating features from dataset file at .
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 536.10it/s]
# convert squad examples to features: 100%|███████████████████████████████████████████████████████████████████████████████| 375/375 [00:01<00:00, 368.27it/s]
# add example index and unique id: 100%|███████████████████████████████████████████████████████████████████████████████████████████| 375/375 [00:00<?, ?it/s]
# 05/06/2020 10:50:01 - INFO - my_run_squad -   Saving features into cached file .\cached_dev_squad_384
# 05/06/2020 10:50:02 - INFO - my_run_squad -   ***** Running evaluation  *****
# 05/06/2020 10:50:02 - INFO - my_run_squad -     Num examples = 500
# 05/06/2020 10:50:02 - INFO - my_run_squad -     Batch size = 64
# Evaluating: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:07<00:00,  1.05it/s]
# 05/06/2020 10:50:10 - INFO - my_run_squad -     Evaluation done in total 7.614066 secs (0.015228 sec per example)
# 05/06/2020 10:50:10 - INFO - transformers.data.metrics.squad_metrics -   Writing predictions to: D:\stanford_courses\nlu-all\final_project\cs224u\dev_notebook\finetune\output_finetuned_model\bioasq_test\predictions_.json
# 05/06/2020 10:50:10 - INFO - transformers.data.metrics.squad_metrics -   Writing nbest to: D:\stanford_courses\nlu-all\final_project\cs224u\dev_notebook\finetune\output_finetuned_model\bioasq_test\nbest_predictions_.json
# 05/06/2020 10:50:15 - INFO - my_run_squad -   Results: {'exact': 36.0, 'f1': 63.49474782894428, 'total': 375, 'HasAns_exact': 36.0, 'HasAns_f1': 63.49474782894428, 'HasAns_total': 375, 'best_exact': 36.0, 'best_exact_thresh': 0.0, 'best_f1': 63.49474782894428, 'best_f1_thresh': 0.0}
# {'exact': 36.0,
#  'f1': 63.49474782894428,
#  'total': 375,
#  'HasAns_exact': 36.0,
#  'HasAns_f1': 63.49474782894428,
#  'HasAns_total': 375,
#  'best_exact': 36.0,
#  'best_exact_thresh': 0.0,
#  'best_f1': 63.49474782894428,
#  'best_f1_thresh': 0.0}

# %%
# bioasq_test set results

{'exact': 36.0,
 'f1': 63.49474782894428,
 'total': 375,
 'HasAns_exact': 36.0,
 'HasAns_f1': 63.49474782894428,
 'HasAns_total': 375,
 'best_exact': 36.0,
 'best_exact_thresh': 0.0,
 'best_f1': 63.49474782894428,
 'best_f1_thresh': 0.0}
