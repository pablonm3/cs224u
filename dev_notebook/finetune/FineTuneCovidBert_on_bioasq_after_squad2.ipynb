# %%
import argparse
import glob
import logging
import os
import random
import timeit

#this reloads the module ( required when we updated the my_run_squad  module offline)
# %load_ext autoreload
# %autoreload 2

import torch
import importlib #import reload
import torch.nn as nn
from transformers import *
from my_run_squad import main as my_main # import main as my_main

#importlib.reload(my_run_squad)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
torch.cuda.empty_cache()
model_path = "output_pretrained_model/covid_pre_trained_bert_v2.0/covid_bert_v2.0"
base_path = os.path.abspath('')
grand_parent_path =os.path.abspath('..\..')
#print(grand_parent_path)

# fine tune with squad v2
out_dir = os.path.join(base_path,"output_finetuned_model", "covidbioasq")
train_dir = os.path.join(base_path,"bioasq_data\\train_combined", "trainset_combined_squad_format.json")
eval_dir = os.path.join(base_path,"bioasq_data\\test_combined", "BioASQ-task8bPhaseB-testset_combined_squad_format.json")
#print(out_dir)
#print(train_dir)
#print(eval_dir)

my_main(model_path,out_dir,train_dir,eval_dir)
# Out:
# {'model_type': 'bert', 'model_name_or_path': 'output_pretrained_model/covid_pre_trained_bert_v2.0/covid_bert_v2.0', 'output_dir': 'D:\\stanford_courses\\nlu-all\\final_project\\cs224u\\dev_notebook\\finetune\\output_finetuned_model\\covidbioasq', 'data_dir': None, 'train_file': 'D:\\stanford_courses\\nlu-all\\final_project\\cs224u\\dev_notebook\\finetune\\bioasq_data\\train_combined\\trainset_combined_squad_format.json', 'predict_file': 'D:\\stanford_courses\\nlu-all\\final_project\\cs224u\\dev_notebook\\finetune\\bioasq_data\\test_combined\\BioASQ-task8bPhaseB-testset_combined_squad_format.json', 'config_name': '', 'tokenizer_name': '', 'cache_dir': '', 'version_2_with_negative': True, 'null_score_diff_threshold': 0.0, 'max_seq_length': 384, 'doc_stride': 128, 'max_query_length': 64, 'do_train': True, 'do_eval': True, 'evaluate_during_training': False, 'do_lower_case': True, 'per_gpu_train_batch_size': 8, 'per_gpu_eval_batch_size': 64, 'learning_rate': 3e-05, 'gradient_accumulation_steps': 1, 'weight_decay': 0.0, 'adam_epsilon': 1e-08, 'max_grad_norm': 1.0, 'num_train_epochs': 3.0, 'max_steps': -1, 'warmup_steps': 550, 'n_best_size': 20, 'max_answer_length': 128, 'verbose_logging': False, 'lang_id': 0, 'logging_steps': 50, 'save_steps': 2000, 'eval_all_checkpoints': False, 'no_cuda': False, 'overwrite_output_dir': False, 'overwrite_cache': False, 'seed': 42, 'local_rank': -1, 'fp16': False, 'fp16_opt_level': None, 'server_ip': '', 'server_port': '', 'threads': 2}
# 05/07/2020 09:27:43 - WARNING - my_run_squad -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 05/07/2020 09:27:43 - INFO - transformers.configuration_utils -   loading configuration file output_pretrained_model/covid_pre_trained_bert_v2.0/covid_bert_v2.0\config.json
# 05/07/2020 09:27:43 - INFO - transformers.configuration_utils -   Model config BertConfig {
#   "_num_labels": 2,
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bad_words_ids": null,
#   "bos_token_id": null,
#   "decoder_start_token_id": null,
#   "do_sample": false,
#   "early_stopping": false,
#   "eos_token_id": null,
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "is_decoder": false,
#   "is_encoder_decoder": false,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1
#   },
#   "language": "english",
#   "layer_norm_eps": 1e-12,
#   "length_penalty": 1.0,
#   "max_length": 20,
#   "max_position_embeddings": 512,
#   "min_length": 0,
#   "model_type": "bert",
#   "name": "Bert",
#   "no_repeat_ngram_size": 0,
#   "num_attention_heads": 12,
#   "num_beams": 1,
#   "num_hidden_layers": 12,
#   "num_return_sequences": 1,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "output_past": true,
#   "pad_token_id": 0,
#   "prefix": null,
#   "pruned_heads": {},
#   "repetition_penalty": 1.0,
#   "task_specific_params": null,
#   "temperature": 1.0,
#   "top_k": 50,
#   "top_p": 1.0,
#   "torchscript": false,
#   "type_vocab_size": 2,
#   "use_bfloat16": false,
#   "vocab_size": 30522
# }
#
# 05/07/2020 09:27:43 - INFO - transformers.configuration_utils -   loading configuration file output_pretrained_model/covid_pre_trained_bert_v2.0/covid_bert_v2.0\config.json
# 05/07/2020 09:27:43 - INFO - transformers.configuration_utils -   Model config BertConfig {
#   "_num_labels": 2,
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bad_words_ids": null,
#   "bos_token_id": null,
#   "decoder_start_token_id": null,
#   "do_sample": false,
#   "early_stopping": false,
#   "eos_token_id": null,
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "is_decoder": false,
#   "is_encoder_decoder": false,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1
#   },
#   "language": "english",
#   "layer_norm_eps": 1e-12,
#   "length_penalty": 1.0,
#   "max_length": 20,
#   "max_position_embeddings": 512,
#   "min_length": 0,
#   "model_type": "bert",
#   "name": "Bert",
#   "no_repeat_ngram_size": 0,
#   "num_attention_heads": 12,
#   "num_beams": 1,
#   "num_hidden_layers": 12,
#   "num_return_sequences": 1,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "output_past": true,
#   "pad_token_id": 0,
#   "prefix": null,
#   "pruned_heads": {},
#   "repetition_penalty": 1.0,
#   "task_specific_params": null,
#   "temperature": 1.0,
#   "top_k": 50,
#   "top_p": 1.0,
#   "torchscript": false,
#   "type_vocab_size": 2,
#   "use_bfloat16": false,
#   "vocab_size": 30522
# }
#
# 05/07/2020 09:27:43 - INFO - transformers.tokenization_utils -   Model name 'output_pretrained_model/covid_pre_trained_bert_v2.0/covid_bert_v2.0' not found in model shortcut name list (bert-base-uncased, bert-large-uncased, bert-base-cased, bert-large-cased, bert-base-multilingual-uncased, bert-base-multilingual-cased, bert-base-chinese, bert-base-german-cased, bert-large-uncased-whole-word-masking, bert-large-cased-whole-word-masking, bert-large-uncased-whole-word-masking-finetuned-squad, bert-large-cased-whole-word-masking-finetuned-squad, bert-base-cased-finetuned-mrpc, bert-base-german-dbmdz-cased, bert-base-german-dbmdz-uncased, bert-base-finnish-cased-v1, bert-base-finnish-uncased-v1, bert-base-dutch-cased). Assuming 'output_pretrained_model/covid_pre_trained_bert_v2.0/covid_bert_v2.0' is a path, a model identifier, or url to a directory containing tokenizer files.
# 05/07/2020 09:27:43 - INFO - transformers.tokenization_utils -   Didn't find file output_pretrained_model/covid_pre_trained_bert_v2.0/covid_bert_v2.0\added_tokens.json. We won't load it.
# 05/07/2020 09:27:43 - INFO - transformers.tokenization_utils -   loading file output_pretrained_model/covid_pre_trained_bert_v2.0/covid_bert_v2.0\vocab.txt
# 05/07/2020 09:27:43 - INFO - transformers.tokenization_utils -   loading file None
# 05/07/2020 09:27:43 - INFO - transformers.tokenization_utils -   loading file output_pretrained_model/covid_pre_trained_bert_v2.0/covid_bert_v2.0\special_tokens_map.json
# 05/07/2020 09:27:43 - INFO - transformers.tokenization_utils -   loading file output_pretrained_model/covid_pre_trained_bert_v2.0/covid_bert_v2.0\tokenizer_config.json
# 05/07/2020 09:27:43 - INFO - transformers.modeling_utils -   loading weights file output_pretrained_model/covid_pre_trained_bert_v2.0/covid_bert_v2.0\pytorch_model.bin
# 05/07/2020 09:27:44 - INFO - transformers.modeling_utils -   Weights of BertForQuestionAnswering not initialized from pretrained model: ['qa_outputs.weight', 'qa_outputs.bias']
# 05/07/2020 09:27:44 - INFO - transformers.modeling_utils -   Weights from pretrained model not used in BertForQuestionAnswering: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight']
# 05/07/2020 09:27:46 - INFO - my_run_squad -   Training/evaluation parameters Namespace(adam_epsilon=1e-08, cache_dir='', config_name='', data_dir=None, device=device(type='cuda'), do_eval=True, do_lower_case=True, do_train=True, doc_stride=128, eval_all_checkpoints=False, evaluate_during_training=False, fp16=False, fp16_opt_level=None, gradient_accumulation_steps=1, lang_id=0, learning_rate=3e-05, local_rank=-1, logging_steps=50, max_answer_length=128, max_grad_norm=1.0, max_query_length=64, max_seq_length=384, max_steps=-1, model_name_or_path='output_pretrained_model/covid_pre_trained_bert_v2.0/covid_bert_v2.0', model_type='bert', n_best_size=20, n_gpu=1, no_cuda=False, null_score_diff_threshold=0.0, num_train_epochs=3.0, output_dir='D:\\stanford_courses\\nlu-all\\final_project\\cs224u\\dev_notebook\\finetune\\output_finetuned_model\\covidbioasq', overwrite_cache=False, overwrite_output_dir=False, per_gpu_eval_batch_size=64, per_gpu_train_batch_size=8, predict_file='D:\\stanford_courses\\nlu-all\\final_project\\cs224u\\dev_notebook\\finetune\\bioasq_data\\test_combined\\BioASQ-task8bPhaseB-testset_combined_squad_format.json', save_steps=2000, seed=42, server_ip='', server_port='', threads=2, tokenizer_name='', train_file='D:\\stanford_courses\\nlu-all\\final_project\\cs224u\\dev_notebook\\finetune\\bioasq_data\\train_combined\\trainset_combined_squad_format.json', verbose_logging=False, version_2_with_negative=True, warmup_steps=550, weight_decay=0.0)
# 05/07/2020 09:27:46 - INFO - my_run_squad -   Creating features from dataset file at .
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3243/3243 [00:12<00:00, 262.11it/s]
# convert squad examples to features: 100%|███████████████████████████████████████████████████████████████████████████| 27312/27312 [02:06<00:00, 215.96it/s]
# add example index and unique id: 100%|██████████████████████████████████████████████████████████████████████████| 27312/27312 [00:00<00:00, 1139678.96it/s]
# 05/07/2020 09:30:11 - INFO - my_run_squad -   Saving features into cached file .\cached_train_covid_bert_v2.0_384
# 05/07/2020 09:31:05 - INFO - my_run_squad -   ***** Running training *****
# 05/07/2020 09:31:05 - INFO - my_run_squad -     Num examples = 38017
# 05/07/2020 09:31:05 - INFO - my_run_squad -     Num Epochs = 3
# 05/07/2020 09:31:05 - INFO - my_run_squad -     Instantaneous batch size per GPU = 8
# 05/07/2020 09:31:05 - INFO - my_run_squad -     Total train batch size (w. parallel, distributed & accumulation) = 8
# 05/07/2020 09:31:05 - INFO - my_run_squad -     Gradient Accumulation steps = 1
# 05/07/2020 09:31:05 - INFO - my_run_squad -     Total optimization steps = 14259
# 05/07/2020 09:31:05 - INFO - my_run_squad -     Starting fine-tuning.
# Epoch:   0%|                                                                                                                         | 0/3 [00:00<?, ?it/s]
# Iteration:   0%|                                                                                                                  | 0/4753 [00:00<?, ?it/s]
# Iteration:   0%|                                                                                                        | 1/4753 [00:00<1:03:24,  1.25it/s]
# Iteration:   0%|                                                                                                        | 2/4753 [00:01<1:00:56,  1.30it/s]
# Iteration:   0%|                                                                                                          | 3/4753 [00:02<54:48,  1.44it/s]
# Iteration:   0%|                                                                                                          | 4/4753 [00:02<50:20,  1.57it/s]
# Iteration:   0%|                                                                                                          | 5/4753 [00:03<47:15,  1.67it/s]
# Iteration:   0%|▏                                                                                                         | 6/4753 [00:03<45:00,  1.76it/s]
# Iteration:   0%|▏                                                                                                         | 7/4753 [00:04<43:26,  1.82it/s]
# Iteration:   0%|▏                                                                                                         | 8/4753 [00:04<42:23,  1.87it/s]
# Iteration:   0%|▏                                                                                                         | 9/4753 [00:05<41:39,  1.90it/s]
# Iteration:   0%|▏                                                                                                        | 10/4753 [00:05<41:07,  1.92it/s]
# Iteration:   0%|▏                                                                                                        | 11/4753 [00:06<40:46,  1.94it/s]
# Iteration:   0%|▎                                                                                                        | 12/4753 [00:06<40:34,  1.95it/s]
# Iteration:   0%|▎                                                                                                        | 13/4753 [00:07<40:24,  1.95it/s]
# Iteration:   0%|▎                                                                                                        | 14/4753 [00:07<40:15,  1.96it/s]
# Iteration:   0%|▎                                                                                                        | 15/4753 [00:08<40:11,  1.97it/s]
# Iteration:   0%|▎                                                                                                        | 16/4753 [00:08<40:06,  1.97it/s]
# Iteration:   0%|▍                                                                                                        | 17/4753 [00:09<40:02,  1.97it/s]
# Iteration:   0%|▍                                                                                                        | 18/4753 [00:09<40:05,  1.97it/s]
# Iteration:   0%|▍                                                                                                        | 19/4753 [00:10<40:08,  1.97it/s]
# Iteration:   0%|▍                                                                                                        | 20/4753 [00:10<40:00,  1.97it/s]
# Iteration:   0%|▍                                                                                                        | 21/4753 [00:11<39:59,  1.97it/s]
# Iteration:   0%|▍                                                                                                        | 22/4753 [00:11<40:21,  1.95it/s]
# Iteration:   0%|▌                                                                                                        | 23/4753 [00:12<40:13,  1.96it/s]
# Iteration:   1%|▌                                                                                                        | 24/4753 [00:12<40:07,  1.96it/s]
# Iteration:   1%|▌                                                                                                        | 25/4753 [00:13<40:02,  1.97it/s]
# Iteration:   1%|▌                                                                                                        | 26/4753 [00:13<40:18,  1.95it/s]
# Iteration:   1%|▌                                                                                                        | 27/4753 [00:14<41:22,  1.90it/s]
# Iteration:   1%|▌                                                                                                        | 28/4753 [00:14<41:05,  1.92it/s]
# Iteration:   1%|▋                                                                                                        | 29/4753 [00:15<40:44,  1.93it/s]
# Iteration:   1%|▋                                                                                                        | 30/4753 [00:15<40:44,  1.93it/s]
# Iteration:   1%|▋                                                                                                        | 31/4753 [00:16<40:32,  1.94it/s]
# Iteration:   1%|▋                                                                                                        | 32/4753 [00:16<40:20,  1.95it/s]
# Iteration:   1%|▋                                                                                                        | 33/4753 [00:17<40:14,  1.95it/s]
# Iteration:   1%|▊                                                                                                        | 34/4753 [00:17<40:55,  1.92it/s]
# Iteration:   1%|▊                                                                                                        | 35/4753 [00:18<40:08,  1.96it/s]
# Iteration:   1%|▊                                                                                                        | 36/4753 [00:18<39:35,  1.99it/s]
# Iteration:   1%|▊                                                                                                        | 37/4753 [00:19<39:13,  2.00it/s]
# Iteration:   1%|▊                                                                                                        | 38/4753 [00:19<38:59,  2.02it/s]
# Iteration:   1%|▊                                                                                                        | 39/4753 [00:20<38:48,  2.02it/s]
# Iteration:   1%|▉                                                                                                        | 40/4753 [00:20<38:40,  2.03it/s]
# Iteration:   1%|▉                                                                                                        | 41/4753 [00:21<38:34,  2.04it/s]
# Iteration:   1%|▉                                                                                                        | 42/4753 [00:21<38:30,  2.04it/s]
# Iteration:   1%|▉                                                                                                        | 43/4753 [00:22<38:26,  2.04it/s]
# Iteration:   1%|▉                                                                                                        | 44/4753 [00:22<38:38,  2.03it/s]
# Iteration:   1%|▉                                                                                                        | 45/4753 [00:23<38:38,  2.03it/s]
# Iteration:   1%|█                                                                                                        | 46/4753 [00:23<38:34,  2.03it/s]
# Iteration:   1%|█                                                                                                        | 47/4753 [00:24<38:30,  2.04it/s]
# Iteration:   1%|█                                                                                                        | 48/4753 [00:24<38:29,  2.04it/s]C:\Users\visha\.conda\envs\nlu\lib\site-packages\torch\optim\lr_scheduler.py:224: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
#
# Iteration:   1%|█                                                                                                        | 49/4753 [00:25<38:33,  2.03it/s]
# Iteration:   1%|█                                                                                                        | 50/4753 [00:25<38:30,  2.04it/s]
# Iteration:   1%|█▏                                                                                                       | 51/4753 [00:26<38:25,  2.04it/s]
# Iteration:   1%|█▏                                                                                                       | 52/4753 [00:26<38:19,  2.04it/s]
# Iteration:   1%|█▏                                                                                                       | 53/4753 [00:27<38:19,  2.04it/s]
# Iteration:   1%|█▏                                                                                                       | 54/4753 [00:27<38:17,  2.05it/s]
# Iteration:   1%|█▏                                                                                                       | 55/4753 [00:28<38:23,  2.04it/s]
# Iteration:   1%|█▏                                                                                                       | 56/4753 [00:28<38:21,  2.04it/s]
# Iteration:   1%|█▎                                                                                                       | 57/4753 [00:29<38:22,  2.04it/s]
# Iteration:   1%|█▎                                                                                                       | 58/4753 [00:29<38:20,  2.04it/s]
# Iteration:   1%|█▎                                                                                                       | 59/4753 [00:30<38:33,  2.03it/s]
# Iteration:   1%|█▎                                                                                                       | 60/4753 [00:30<38:26,  2.03it/s]
# Iteration:   1%|█▎                                                                                                       | 61/4753 [00:31<38:23,  2.04it/s]
# Iteration:   1%|█▎                                                                                                       | 62/4753 [00:31<38:22,  2.04it/s]
# Iteration:   1%|█▍                                                                                                       | 63/4753 [00:32<38:21,  2.04it/s]
# Iteration:   1%|█▍                                                                                                       | 64/4753 [00:32<38:22,  2.04it/s]
# Iteration:   1%|█▍                                                                                                       | 65/4753 [00:33<38:20,  2.04it/s]
# Iteration:   1%|█▍                                                                                                       | 66/4753 [00:33<38:19,  2.04it/s]
# Iteration:   1%|█▍                                                                                                       | 67/4753 [00:34<38:26,  2.03it/s]
# Iteration:   1%|█▌                                                                                                       | 68/4753 [00:34<38:53,  2.01it/s]
# Iteration:   1%|█▌                                                                                                       | 69/4753 [00:35<39:31,  1.98it/s]
# Iteration:   1%|█▌                                                                                                       | 70/4753 [00:35<39:10,  1.99it/s]
# Iteration:   1%|█▌                                                                                                       | 71/4753 [00:36<38:55,  2.01it/s]
# Iteration:   2%|█▌                                                                                                       | 72/4753 [00:36<38:43,  2.01it/s]
# Iteration:   2%|█▌                                                                                                       | 73/4753 [00:37<38:33,  2.02it/s]
# Iteration:   2%|█▋                                                                                                       | 74/4753 [00:37<38:25,  2.03it/s]
# Iteration:   2%|█▋                                                                                                       | 75/4753 [00:38<38:19,  2.03it/s]
# Iteration:   2%|█▋                                                                                                       | 76/4753 [00:38<38:21,  2.03it/s]
# Iteration:   2%|█▋                                                                                                       | 77/4753 [00:38<38:19,  2.03it/s]
# Iteration:   2%|█▋                                                                                                       | 78/4753 [00:39<38:18,  2.03it/s]
# Iteration:   2%|█▋                                                                                                       | 79/4753 [00:39<38:16,  2.03it/s]
# Iteration:   2%|█▊                                                                                                       | 80/4753 [00:40<38:15,  2.04it/s]
# Iteration:   2%|█▊                                                                                                       | 81/4753 [00:40<38:19,  2.03it/s]
# Iteration:   2%|█▊                                                                                                       | 82/4753 [00:41<38:21,  2.03it/s]
# Iteration:   2%|█▊                                                                                                       | 83/4753 [00:41<38:41,  2.01it/s]
# Iteration:   2%|█▊                                                                                                       | 84/4753 [00:42<38:34,  2.02it/s]
# Iteration:   2%|█▉                                                                                                       | 85/4753 [00:42<38:24,  2.03it/s]
# Iteration:   2%|█▉                                                                                                       | 86/4753 [00:43<38:19,  2.03it/s]
# Iteration:   2%|█▉                                                                                                       | 87/4753 [00:43<38:21,  2.03it/s]
# Iteration:   2%|█▉                                                                                                       | 88/4753 [00:44<38:19,  2.03it/s]
  2.02it/s]
# Iteration:   5%|█████                                                                                                   | 229/4753 [01:54<37:22,  2.02it/s]
# Iteration:   5%|█████                                                                                                   | 230/4753 [01:54<37:23,  2.02it/s]
# Iteration:   5%|█████                                                                                                   | 231/4753 [01:55<37:21,  2.02it/s]
# Iteration:   5%|█████                                                                                                   | 232/4753 [01:55<37:21,  2.02it/s]
# Iteration:   5%|█████                                                                                                   | 233/4753 [01:56<37:21,  2.02it/s]
# Iteration:   5%|█████                                                                                                   | 234/4753 [01:56<37:22,  2.02it/s]
# Iteration:   5%|█████▏                                                                                                  | 235/4753 [01:57<37:17,  2.02it/s]
# Iteration:   5%|█████▏                                                                                                  | 236/4753 [01:57<37:17,  2.02it/s]
# Iteration:   5%|█████▏                                                                                                  | 237/4753 [01:58<37:17,  2.02it/s]
# Iteration:   5%|█████▏                                                                                                  | 238/4753 [01:58<37:21,  2.01it/s]
# Iteration:   5%|█████▏                                                                                                  | 239/4753 [01:59<37:17,  2.02it/s]
# Iteration:   5%|█████▎                                                                                                  | 240/4753 [01:59<37:19,  2.02it/s]
# ...
# Iteration:  99%|██████████████████████████████████████████████████████████████████████████████████████████████████████▎| 4719/4753 [40:01<00:17,  1.96it/s]
# Iteration:  99%|██████████████████████████████████████████████████████████████████████████████████████████████████████▎| 4720/4753 [40:01<00:16,  1.97it/s]
# Iteration:  99%|██████████████████████████████████████████████████████████████████████████████████████████████████████▎| 4721/4753 [40:02<00:16,  1.97it/s]
# Iteration:  99%|██████████████████████████████████████████████████████████████████████████████████████████████████████▎| 4722/4753 [40:02<00:15,  1.97it/s]
# Iteration:  99%|██████████████████████████████████████████████████████████████████████████████████████████████████████▎| 4723/4753 [40:03<00:15,  1.98it/s]
# Iteration:  99%|██████████████████████████████████████████████████████████████████████████████████████████████████████▎| 4724/4753 [40:03<00:14,  1.97it/s]
# Iteration:  99%|██████████████████████████████████████████████████████████████████████████████████████████████████████▍| 4725/4753 [40:04<00:14,  1.98it/s]
# Iteration:  99%|██████████████████████████████████████████████████████████████████████████████████████████████████████▍| 4726/4753 [40:04<00:13,  1.98it/s]
# Iteration:  99%|██████████████████████████████████████████████████████████████████████████████████████████████████████▍| 4727/4753 [40:05<00:13,  1.98it/s]
# Iteration:  99%|██████████████████████████████████████████████████████████████████████████████████████████████████████▍| 4728/4753 [40:05<00:12,  1.97it/s]
# Iteration:  99%|██████████████████████████████████████████████████████████████████████████████████████████████████████▍| 4729/4753 [40:06<00:12,  1.98it/s]
# Iteration: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████▌| 4730/4753 [40:06<00:11,  1.98it/s]
# Iteration: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████▌| 4731/4753 [40:07<00:11,  1.98it/s]
# Iteration: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████▌| 4732/4753 [40:07<00:10,  1.98it/s]
# Iteration: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████▌| 4733/4753 [40:08<00:10,  1.99it/s]
# Iteration: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████▌| 4734/4753 [40:08<00:09,  1.98it/s]
# Iteration: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████▌| 4735/4753 [40:09<00:09,  1.98it/s]
# Iteration: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████▋| 4736/4753 [40:09<00:08,  1.98it/s]
# Iteration: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████▋| 4737/4753 [40:10<00:08,  1.97it/s]
# Iteration: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████▋| 4738/4753 [40:10<00:07,  1.98it/s]
# Iteration: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████▋| 4739/4753 [40:11<00:07,  1.97it/s]
# Iteration: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████▋| 4740/4753 [40:11<00:06,  1.98it/s]
# Iteration: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████▋| 4741/4753 [40:12<00:06,  1.98it/s]
# Iteration: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████▊| 4742/4753 [40:12<00:05,  1.98it/s]
# Iteration: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████▊| 4743/4753 [40:13<00:05,  1.98it/s]
# Iteration: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████▊| 4744/4753 [40:13<00:04,  1.98it/s]
# Iteration: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████▊| 4745/4753 [40:14<00:04,  1.98it/s]
# Iteration: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████▊| 4746/4753 [40:14<00:03,  1.98it/s]
# Iteration: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████▊| 4747/4753 [40:15<00:03,  1.98it/s]
# Iteration: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████▉| 4748/4753 [40:15<00:02,  1.99it/s]
# Iteration: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████▉| 4749/4753 [40:16<00:02,  1.99it/s]
# Iteration: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████▉| 4750/4753 [40:16<00:01,  1.98it/s]
# Iteration: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████▉| 4751/4753 [40:17<00:01,  1.98it/s]
# Iteration: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████▉| 4752/4753 [40:17<00:00,  1.98it/s]
# Iteration: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 4753/4753 [40:18<00:00,  1.97it/s]
# Epoch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [2:00:38<00:00, 2412.77s/it]
# 05/07/2020 11:31:43 - INFO - my_run_squad -    global_step = 14260, average loss = 1.5128379204852551
# 05/07/2020 11:31:43 - INFO - my_run_squad -   Saving model checkpoint to D:\stanford_courses\nlu-all\final_project\cs224u\dev_notebook\finetune\output_finetuned_model\covidbioasq
# 05/07/2020 11:31:43 - INFO - transformers.configuration_utils -   Configuration saved in D:\stanford_courses\nlu-all\final_project\cs224u\dev_notebook\finetune\output_finetuned_model\covidbioasq\config.json
# 05/07/2020 11:31:44 - INFO - transformers.modeling_utils -   Model weights saved in D:\stanford_courses\nlu-all\final_project\cs224u\dev_notebook\finetune\output_finetuned_model\covidbioasq\pytorch_model.bin
# 05/07/2020 11:31:44 - INFO - transformers.configuration_utils -   loading configuration file D:\stanford_courses\nlu-all\final_project\cs224u\dev_notebook\finetune\output_finetuned_model\covidbioasq\config.json
# 05/07/2020 11:31:44 - INFO - transformers.configuration_utils -   Model config BertConfig {
#   "_num_labels": 2,
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bad_words_ids": null,
#   "bos_token_id": null,
#   "decoder_start_token_id": null,
#   "do_sample": false,
#   "early_stopping": false,
#   "eos_token_id": null,
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "is_decoder": false,
#   "is_encoder_decoder": false,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1
#   },
#   "language": "english",
#   "layer_norm_eps": 1e-12,
#   "length_penalty": 1.0,
#   "max_length": 20,
#   "max_position_embeddings": 512,
#   "min_length": 0,
#   "model_type": "bert",
#   "name": "Bert",
#   "no_repeat_ngram_size": 0,
#   "num_attention_heads": 12,
#   "num_beams": 1,
#   "num_hidden_layers": 12,
#   "num_return_sequences": 1,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "output_past": true,
#   "pad_token_id": 0,
#   "prefix": null,
#   "pruned_heads": {},
#   "repetition_penalty": 1.0,
#   "task_specific_params": null,
#   "temperature": 1.0,
#   "top_k": 50,
#   "top_p": 1.0,
#   "torchscript": false,
#   "type_vocab_size": 2,
#   "use_bfloat16": false,
#   "vocab_size": 30522
# }
#
# 05/07/2020 11:31:44 - INFO - transformers.modeling_utils -   loading weights file D:\stanford_courses\nlu-all\final_project\cs224u\dev_notebook\finetune\output_finetuned_model\covidbioasq\pytorch_model.bin
# 05/07/2020 11:31:46 - INFO - transformers.configuration_utils -   loading configuration file D:\stanford_courses\nlu-all\final_project\cs224u\dev_notebook\finetune\output_finetuned_model\covidbioasq\config.json
# 05/07/2020 11:31:46 - INFO - transformers.configuration_utils -   Model config BertConfig {
#   "_num_labels": 2,
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bad_words_ids": null,
#   "bos_token_id": null,
#   "decoder_start_token_id": null,
#   "do_sample": false,
#   "early_stopping": false,
#   "eos_token_id": null,
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "is_decoder": false,
#   "is_encoder_decoder": false,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1
#   },
#   "language": "english",
#   "layer_norm_eps": 1e-12,
#   "length_penalty": 1.0,
#   "max_length": 20,
#   "max_position_embeddings": 512,
#   "min_length": 0,
#   "model_type": "bert",
#   "name": "Bert",
#   "no_repeat_ngram_size": 0,
#   "num_attention_heads": 12,
#   "num_beams": 1,
#   "num_hidden_layers": 12,
#   "num_return_sequences": 1,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "output_past": true,
#   "pad_token_id": 0,
#   "prefix": null,
#   "pruned_heads": {},
#   "repetition_penalty": 1.0,
#   "task_specific_params": null,
#   "temperature": 1.0,
#   "top_k": 50,
#   "top_p": 1.0,
#   "torchscript": false,
#   "type_vocab_size": 2,
#   "use_bfloat16": false,
#   "vocab_size": 30522
# }
# 05/07/2020 11:31:46 - INFO - transformers.tokenization_utils -   Model name 'D:\stanford_courses\nlu-all\final_project\cs224u\dev_notebook\finetune\output_finetuned_model\covidbioasq' not found in model shortcut name list (bert-base-uncased, bert-large-uncased, bert-base-cased, bert-large-cased, bert-base-multilingual-uncased, bert-base-multilingual-cased, bert-base-chinese, bert-base-german-cased, bert-large-uncased-whole-word-masking, bert-large-cased-whole-word-masking, bert-large-uncased-whole-word-masking-finetuned-squad, bert-large-cased-whole-word-masking-finetuned-squad, bert-base-cased-finetuned-mrpc, bert-base-german-dbmdz-cased, bert-base-german-dbmdz-uncased, bert-base-finnish-cased-v1, bert-base-finnish-uncased-v1, bert-base-dutch-cased). Assuming 'D:\stanford_courses\nlu-all\final_project\cs224u\dev_notebook\finetune\output_finetuned_model\covidbioasq' is a path, a model identifier, or url to a directory containing tokenizer files.
# 05/07/2020 11:31:46 - INFO - transformers.tokenization_utils -   Didn't find file D:\stanford_courses\nlu-all\final_project\cs224u\dev_notebook\finetune\output_finetuned_model\covidbioasq\added_tokens.json. We won't load it.
# 05/07/2020 11:31:46 - INFO - transformers.tokenization_utils -   loading file D:\stanford_courses\nlu-all\final_project\cs224u\dev_notebook\finetune\output_finetuned_model\covidbioasq\vocab.txt
# 05/07/2020 11:31:46 - INFO - transformers.tokenization_utils -   loading file None
# 05/07/2020 11:31:46 - INFO - transformers.tokenization_utils -   loading file D:\stanford_courses\nlu-all\final_project\cs224u\dev_notebook\finetune\output_finetuned_model\covidbioasq\special_tokens_map.json
# 05/07/2020 11:31:46 - INFO - transformers.tokenization_utils -   loading file D:\stanford_courses\nlu-all\final_project\cs224u\dev_notebook\finetune\output_finetuned_model\covidbioasq\tokenizer_config.json
# 05/07/2020 11:31:46 - INFO - my_run_squad -   Loading checkpoints saved during training for evaluation
# 05/07/2020 11:31:46 - INFO - my_run_squad -   Evaluate the following checkpoints: ['D:\\stanford_courses\\nlu-all\\final_project\\cs224u\\dev_notebook\\finetune\\output_finetuned_model\\covidbioasq']
# 05/07/2020 11:31:46 - INFO - transformers.configuration_utils -   loading configuration file D:\stanford_courses\nlu-all\final_project\cs224u\dev_notebook\finetune\output_finetuned_model\covidbioasq\config.json
# 05/07/2020 11:31:46 - INFO - transformers.configuration_utils -   Model config BertConfig {
#   "_num_labels": 2,
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bad_words_ids": null,
#   "bos_token_id": null,
#   "decoder_start_token_id": null,
#   "do_sample": false,
#   "early_stopping": false,
#   "eos_token_id": null,
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "is_decoder": false,
#   "is_encoder_decoder": false,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1
#   },
#   "language": "english",
#   "layer_norm_eps": 1e-12,
#   "length_penalty": 1.0,
#   "max_length": 20,
#   "max_position_embeddings": 512,
#   "min_length": 0,
#   "model_type": "bert",
#   "name": "Bert",
#   "no_repeat_ngram_size": 0,
#   "num_attention_heads": 12,
#   "num_beams": 1,
#   "num_hidden_layers": 12,
#   "num_return_sequences": 1,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "output_past": true,
#   "pad_token_id": 0,
#   "prefix": null,
#   "pruned_heads": {},
#   "repetition_penalty": 1.0,
#   "task_specific_params": null,
#   "temperature": 1.0,
#   "top_k": 50,
#   "top_p": 1.0,
#   "torchscript": false,
#   "type_vocab_size": 2,
#   "use_bfloat16": false,
#   "vocab_size": 30522
# }
#
# 05/07/2020 11:31:46 - INFO - transformers.modeling_utils -   loading weights file D:\stanford_courses\nlu-all\final_project\cs224u\dev_notebook\finetune\output_finetuned_model\covidbioasq\pytorch_model.bin
# 05/07/2020 11:31:48 - INFO - my_run_squad -   Creating features from dataset file at .
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 500/500 [00:00<00:00, 589.12it/s]
# convert squad examples to features: 100%|█████████████████████████████████████████████████████████████████████████████| 1798/1798 [00:08<00:00, 200.11it/s]
# add example index and unique id: 100%|█████████████████████████████████████████████████████████████████████████████| 1798/1798 [00:00<00:00, 901213.98it/s]
# 05/07/2020 11:32:06 - INFO - my_run_squad -   Saving features into cached file .\cached_dev_covid_bert_v2.0_384
# 05/07/2020 11:32:09 - INFO - my_run_squad -   ***** Running evaluation  *****
# 05/07/2020 11:32:09 - INFO - my_run_squad -     Num examples = 2753
# 05/07/2020 11:32:09 - INFO - my_run_squad -     Batch size = 64
# Evaluating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████| 44/44 [00:51<00:00,  1.16s/it]
# 05/07/2020 11:33:00 - INFO - my_run_squad -     Evaluation done in total 51.069491 secs (0.018550 sec per example)
# 05/07/2020 11:33:00 - INFO - transformers.data.metrics.squad_metrics -   Writing predictions to: D:\stanford_courses\nlu-all\final_project\cs224u\dev_notebook\finetune\output_finetuned_model\covidbioasq\predictions_.json
# 05/07/2020 11:33:00 - INFO - transformers.data.metrics.squad_metrics -   Writing nbest to: D:\stanford_courses\nlu-all\final_project\cs224u\dev_notebook\finetune\output_finetuned_model\covidbioasq\nbest_predictions_.json
# 05/07/2020 11:33:20 - INFO - my_run_squad -   Results: {'exact': 37.096774193548384, 'f1': 60.706622318782976, 'total': 1798, 'HasAns_exact': 37.096774193548384, 'HasAns_f1': 60.706622318782976, 'HasAns_total': 1798, 'best_exact': 37.096774193548384, 'best_exact_thresh': 0.0, 'best_f1': 60.706622318782976, 'best_f1_thresh': 0.0}
# {'exact': 37.096774193548384,
#  'f1': 60.706622318782976,
#  'total': 1798,
#  'HasAns_exact': 37.096774193548384,
#  'HasAns_f1': 60.706622318782976,
#  'HasAns_total': 1798,
#  'best_exact': 37.096774193548384,
#  'best_exact_thresh': 0.0,
#  'best_f1': 60.706622318782976,
#  'best_f1_thresh': 0.0}

# %%
{'exact': 37.096774193548384,
 'f1': 60.706622318782976,
 'total': 1798,
 'HasAns_exact': 37.096774193548384,
 'HasAns_f1': 60.706622318782976,
 'HasAns_total': 1798,
 'best_exact': 37.096774193548384,
 'best_exact_thresh': 0.0,
 'best_f1': 60.706622318782976,
 'best_f1_thresh': 0.0}
